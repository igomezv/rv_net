# %% [markdown]
# # dace-query sun script
#
# For more documentation, see: https://dace-query.readthedocs.io/en/latest/dace_query.sun.html
#
# For modifying the query, see: https://dace-query.readthedocs.io/en/latest/query_options.html

# %%
# run the installation
! pip install dace-query

# only run this once and then comment this line out.
# Out:
# Requirement already satisfied: dace-query in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: pandas<2.0.0,>=1.5.1 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from dace-query) (1.5.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from dace-query) (2.31.0)
# Requirement already satisfied: astropy<6.0.0,>=5.1.1 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from dace-query) (5.3.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.4 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from dace-query) (1.25.1)
# Requirement already satisfied: packaging>=19.0 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from astropy<6.0.0,>=5.1.1->dace-query) (21.3)
# Requirement already satisfied: pyerfa>=2.0 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from astropy<6.0.0,>=5.1.1->dace-query) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from astropy<6.0.0,>=5.1.1->dace-query) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from packaging>=19.0->astropy<6.0.0,>=5.1.1->dace-query) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.5.1->dace-query) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.5.1->dace-query) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.5.1->dace-query) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->dace-query) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->dace-query) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->dace-query) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->dace-query) (3.3)

# %% [markdown]
# ## To be able to login into DACE and download their data, we need a file called .dacerc
#
# In your command prompt type: 'printf '[user]\nkey = apiKey:%s\n' "7b77ad40-1047-4c44-9103-fdba0bbb07ee" > ~/.dacerc'

# %%
# import packages
import numpy as np
#import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
from dace_query.sun import Sun

#globally change font size for plots
plt.rcParams['font.size'] =17
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
# Download all the data

# change this path to your local path
output_directory = '/Users/zdebeurs/Documents/Github/rv_net/'
output_filename = 'public_release_timeseries.csv'


# Download solar data from DACE. (This take a while to run)
values = Sun.get_timeseries()

# %%
# read data into DataFrame format
df_values = pd.DataFrame(values)

# Write to csv
df_values.to_csv(output_filename)

# print dataframe contents
df_values
# Out:
#                                    filename instrument      date_bjd       rv  \
# 0      r.HARPN.2015-07-29T09-01-42.883.fits      HARPN  57232.872837  104.663
# 1      r.HARPN.2015-07-29T09-07-07.038.fits      HARPN  57232.876590  104.081
# 2      r.HARPN.2015-07-29T09-12-32.347.fits      HARPN  57232.880365  103.631
# 3      r.HARPN.2015-07-29T09-17-56.902.fits      HARPN  57232.884111  103.987
# 4      r.HARPN.2015-07-29T09-23-22.210.fits      HARPN  57232.887876  103.629
# ...                                     ...        ...           ...      ...
# 49995  r.HARPN.2018-05-24T10-40-14.246.fits      HARPN  58262.941328  100.597
# 49996  r.HARPN.2018-05-24T10-45-40.543.fits      HARPN  58262.945105  100.559
# 49997  r.HARPN.2018-05-24T10-51-06.807.fits      HARPN  58262.948882  100.350
# 49998  r.HARPN.2018-05-24T10-56-34.252.fits      HARPN  58262.952675   99.287
# 49999  r.HARPN.2018-05-24T11-02-00.902.fits      HARPN  58262.956453  100.153
#
#           rhk  rv_diff_extinction  sn_order_50   airmass   contrast  \
# 0     -4.9711               0.483   443.406922  1.902923  56.214329
# 1     -4.9670               0.448   444.458534  1.846167  56.203232
# 2     -4.9678               0.416   445.837656  1.789318  56.198806
# 3     -4.9684               0.387   447.174561  1.734415  56.202176
# 4     -4.9677               0.361   448.109010  1.681493  56.202143
# ...       ...                 ...          ...       ...        ...
# 49995 -5.0026               0.141   360.364089  1.203356  56.344475
# 49996 -5.0057               0.132   360.398642  1.187113  56.350717
# 49997 -5.0046               0.124   360.827980  1.171826  56.342180
# 49998 -5.0046               0.117   361.153361  1.157344  56.341825
# 49999 -5.0013               0.109   361.368444  1.143841  56.335987
#
#        drs_quality  ...        berv  sn_order_10  berv_bary_to_helio  \
# 0             True  ...  551.642661   158.757508               6.696
# 1             True  ...  547.508392   159.846462               6.696
# 2             True  ...  543.159042   160.991720               6.695
# 3             True  ...  538.656755   162.004650               6.694
# 4             True  ...  533.945277   162.979005               6.694
# ...            ...  ...         ...          ...                 ...
# 49995         True  ...  -79.753014   148.161265               0.773
# 49996         True  ...  -87.064207   148.428463               0.774
# 49997         True  ...  -94.501120   148.677980               0.775
# 49998         True  ... -102.086406   148.926317               0.776
# 49999         True  ... -109.759896   149.110075               0.777
#
#           fwhm_raw  fwhm_err  sn_order_30   texp  date_night prog_id  public
# 0      7056.952506  0.467915   366.773666  300.0  2015-07-29   SOLAR    True
# 1      7058.731768  0.466367   368.192052  300.0  2015-07-29   SOLAR    True
# 2      7060.160638  0.464675   369.748465  300.0  2015-07-29   SOLAR    True
# 3      7059.411777  0.462926   371.206129  300.0  2015-07-29   SOLAR    True
# 4      7057.955713  0.461405   372.444190  300.0  2015-07-29   SOLAR    True
# ...            ...       ...          ...    ...         ...     ...     ...
# 49995  7057.089334  0.541591   294.941547  300.0  2018-05-24   SOLAR   False
# 49996  7059.700549  0.541232   295.176195  300.0  2018-05-24   SOLAR   False
# 49997  7059.137165  0.540900   295.475267  300.0  2018-05-24   SOLAR   False
# 49998  7058.787995  0.540283   295.800518  300.0  2018-05-24   SOLAR   False
# 49999  7059.407767  0.540010   296.063949  300.0  2018-05-24   SOLAR   False
#
# [50000 rows x 35 columns]

# %%
query_test = Sun.query_database(limit=100000)

# %%
np.sort(query_test['date_night'])
# Out:
# array(['2015-07-29', '2015-07-29', '2015-07-29', ..., '2022-10-15',
#        '2022-10-15', '2022-10-15'], dtype='<U10')
